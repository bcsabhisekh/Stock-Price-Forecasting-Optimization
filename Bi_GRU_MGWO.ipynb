# %%
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import random as random
import copy as copy
from sklearn.metrics import mean_squared_error
import math

# %%
data = yf.download('MSFT', '2013-01-01', '2023-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2013-01-02  27.250000  27.730000  27.150000  27.620001  22.668228  52899300
# 2013-01-03  27.629999  27.650000  27.160000  27.250000  22.364565  48294400
# 2013-01-04  27.270000  27.340000  26.730000  26.740000  21.945993  52521100
# 2013-01-07  26.770000  26.879999  26.639999  26.690001  21.904963  37110400
# 2013-01-08  26.750000  26.790001  26.459999  26.549999  21.790060  44703100

# %%
def normalize_dataset(inputs, outputs):
  normalized_inputs = []

  mins = [np.min(inputs[:, col_idx]) for col_idx in range(inputs.shape[1])]
  maxs = [np.max(inputs[:, col_idx]) for col_idx in range(inputs.shape[1])]

  for vector in inputs:
    normalized_vector = []
    for col_idx in range(vector.shape[0]):
      normalized_vector.append((vector[col_idx] - mins[col_idx]) / (maxs[col_idx] - mins[col_idx]))
    normalized_inputs.append(normalized_vector)

  min_output = np.min(outputs)
  max_output = np.max(outputs)

  normalized_outputs = [(x - min_output) / (max_output - min_output) for x in outputs]

  return np.array(normalized_inputs), np.array(normalized_outputs)


def smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))

# %%
# function to modify the dataset using sliding window
# takes the last 'window_size' days' features and concatenates them horizontally to get n * window_size size input vector
# this is used and input to predict the closing price for the current day
def dataset_preparation(window_size = 1, train_test_split_year = 2020): # assumes the default window size to be 1

    # preparing the training dataset
    filt = data.index.year <= train_test_split_year
    train_df = data.loc[filt]

    X_train = []
    y_train = []

    # mins = [1e7 for i in range(6)]
    # maxs = [0 for i in range(6)]

    for i in range(window_size, len(train_df.values)):
        feature_set = []

        for j in range(i - 1, i - window_size, -1):
            feature_set.append(train_df.values[j][3])

        X_train.append(feature_set[::-1])
        y_train.append(train_df.iloc[i, 3]) # closing price

    X_train = np.array(X_train)
    y_train = np.array(y_train)

    X_train, y_train = normalize_dataset(X_train, y_train)

    # preparing the testing dataset
    test_df = data.loc[~filt]

    X_test = []
    y_test = []

    for i in range(window_size, len(test_df.values)):
        feature_set = []
        for j in range(i - 1, i - window_size, -1):
            feature_set.append(test_df.values[j][3])
        X_test.append(feature_set[::-1])
        y_test.append(test_df.iloc[i, 3]) # closing price

    # converting lists to ndarrays

    X_test = np.array(X_test)
    y_test = np.array(y_test)

    X_test, y_test = normalize_dataset(X_test, y_test)

    print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

    # reshaping the training and testing inputs for RNN variants
    X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
    X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

    return X_train, X_test, y_train, y_test

# %%
# # function to modify the dataset using sliding window
# # takes the last 'window_size' days' features and concatenates them horizontally to get n * window_size size input vector
# # this is used and input to predict the closing price for the current day
# def dataset_preparation(window_size = 1, train_test_split_year = 2020): # assumes the default window size to be 1

#     # preparing the training dataset
#     filt = data.index.year <= train_test_split_year
#     train_df = data.loc[filt]

#     X_train = []
#     y_train = []

#     # mins = [1e7 for i in range(6)]
#     # maxs = [0 for i in range(6)]

#     for i in range(window_size, len(train_df.values)):
#         feature_set = []

#         for j in range(i - 1, i - window_size, -1):
#             feature_set.append(train_df.values[j])
#             # for k, val in enumerate(feature_set[-1]):
#             #   mins[k] = np.min(mins[k], val)
#             #   maxs[k] = np.max(maxs[k], val)
#         X_train.append(feature_set)
#         y_train.append(train_df.iloc[i, 3]) # closing price

#     X_train = np.array(X_train)
#     y_train = np.array(y_train)

#     # for sample in X_train:
#     #   for j in range(len(sample)):



#     # preparing the testing dataset
#     test_df = data.loc[~filt]

#     X_test = []
#     y_test = []

#     for i in range(window_size, len(test_df.values)):
#         feature_set = []
#         for j in range(i - 1, i - window_size, -1):
#             feature_set.append(test_df.values[j])
#         X_test.append(feature_set)
#         y_test.append(test_df.iloc[i, 3]) # closing price

#     # converting lists to ndarrays

#     X_test = np.array(X_test)

#     y_test = np.array(y_test)

#     # reshaping the training and testing inputs for RNN variants
#     X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] * X_train.shape[2], 1)
#     X_test = X_test.reshape(X_test.shape[0], X_test.shape[1] * X_test.shape[2], 1)

#     return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = dataset_preparation(window_size = 8, train_test_split_year = 2020)
# Out:
# (2007, 7) (495, 7) (2007,) (495,)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# print(X_train[0:5])
# Out:
# (2007, 7, 1) (495, 7, 1) (2007,) (495,)

# %%
# util functions

def get_predictions(model, inputs):
    predictions = model.predict(inputs)
    predictions = predictions.reshape(predictions.size)
    return predictions

def mean_absolute_error(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

def mean_squared_error(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred) ** 2)

def plot_predictions(original, predicted, title = 'true values vs predicted values'):
    original_data = original
    predicted_data = predicted

    plt.figure()
    plt.plot(original_data, label='Original Data')
    plt.plot(predicted_data, label='Predicted Data')

    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title(title)
    plt.grid(True)
    plt.legend()

    plt.show()

# %%
model = keras.Sequential()
model.add(layers.Bidirectional(layers.GRU(120, input_shape = (X_train.shape[1], X_train.shape[2]))))
model.add(layers.Dense(1, activation = 'sigmoid'))
# model.summary()

# %%
# training the model with backpropagation

model.compile(loss = 'mean_absolute_error', optimizer = 'adam')
model.fit(X_train, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 63/63 [==============================] - 10s 5ms/step - loss: 0.1006
# Epoch 2/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0212
# Epoch 3/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0210
# Epoch 4/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0182
# Epoch 5/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0121
# Epoch 6/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0107
# Epoch 7/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0104
# Epoch 8/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0096
# Epoch 9/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0107
# Epoch 10/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 11/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0096
# Epoch 12/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 13/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0094
# Epoch 14/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0085
# Epoch 15/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0087
# Epoch 16/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0087
# Epoch 17/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0085
# Epoch 18/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0091
# Epoch 19/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0084
# Epoch 20/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0083
# Epoch 21/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 22/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0086
# Epoch 23/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0086
# Epoch 24/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 25/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 26/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 27/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0095
# Epoch 28/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0090
# Epoch 29/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0088
# Epoch 30/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0086
# Epoch 31/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 32/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0082
# Epoch 33/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0088
# Epoch 34/100
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0082
# Epoch 35/100
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0081
# Epoch 36/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0080
# Epoch 37/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0085
# Epoch 38/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0083
# Epoch 39/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0078
# Epoch 40/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0081
# Epoch 41/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 42/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 43/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0080
# Epoch 44/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 45/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0078
# Epoch 46/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0083
# Epoch 47/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 48/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 49/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 50/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 51/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 52/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 53/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 54/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 55/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 56/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0071
# Epoch 57/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 58/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0078
# Epoch 59/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 60/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 61/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 62/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 63/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 64/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 65/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0077
# Epoch 66/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0079
# Epoch 67/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 68/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 69/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 70/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 71/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0071
# Epoch 72/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0073
# Epoch 73/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 74/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 75/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0072
# Epoch 76/100
# 63/63 [==============================] - 0s 6ms/step - loss: 0.0076
# Epoch 77/100
# 63/63 [==============================] - 0s 7ms/step - loss: 0.0072
# Epoch 78/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 79/100
# 63/63 [==============================] - 0s 4ms/step - loss: 0.0071
# Epoch 80/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0075
# Epoch 81/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 82/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 83/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 84/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0071
# Epoch 85/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0076
# Epoch 86/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0070
# Epoch 87/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0069
# Epoch 88/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 89/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 90/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 91/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0069
# Epoch 92/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0073
# Epoch 93/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 94/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 95/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0067
# Epoch 96/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 97/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0068
# Epoch 98/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0072
# Epoch 99/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0066
# Epoch 100/100
# 63/63 [==============================] - 0s 5ms/step - loss: 0.0072

# %%
lower_bound = 1
upper_bound = 1
for layer in model.layers:
        weights = layer.get_weights()
        for w in weights:
            lower_bound = min(lower_bound, np.min(w))
            upper_bound = max(upper_bound, np.max(w))

print(lower_bound, upper_bound)
# Out:
# -1.0519934 1.1261427

# %%
train_predictions = get_predictions(model, X_train)
test_predictions = get_predictions(model, X_test)
plot_predictions(y_test, test_predictions, 'performance on test data')
plot_predictions(y_train, train_predictions, 'performance on training data')
# Out:
# 63/63 [==============================] - 1s 2ms/step
# 16/16 [==============================] - 0s 2ms/step

# %%
LSTM_MSE = mean_squared_error(y_test, test_predictions)
LSTM_MAE = mean_absolute_error(y_test, test_predictions)
LSTM_RMSE = math.sqrt(LSTM_MSE)
LSTM_SMAPE = smape(y_test, test_predictions)
LSTM_MSE_T = mean_squared_error(y_train, train_predictions)
LSTM_MAE_T = mean_absolute_error(y_train, train_predictions)
LSTM_RMSE_T = math.sqrt(LSTM_MSE)
LSTM_SMAPE_T = smape(y_train, train_predictions)
print('Training MAE - ', LSTM_MAE)
print('Testing MAE - ', LSTM_MAE_T)
# Out:
# Training MAE -  0.036550757619156826
# Testing MAE -  0.006031608402232635

# %%
# # arr = list(np.zeros(100000000000))
# # Manually update the weights
def update_weights(position):
    idx = 0
    for layer in model.layers:
        weights = layer.get_weights()
        # new_weights = [np.zeros(w.shape) for w in weights]
        new_weights = []
        for w in weights:
            tmp_arr = position[idx]
            idx = idx + 1
            tmp_arr = list(np.reshape(np.array(tmp_arr),w.shape))
            new_weights.append(np.array(tmp_arr, dtype='f'))
        # print(new_weights)
        layer.set_weights(new_weights)
        # for w in weights:
        #     print(w.shape)


def get_weights():
    new_weights = []
    for layer in model.layers:
        weights = layer.get_weights()
        # new_weights = [np.zeros(w.shape) for w in weights]
        for w in weights:
            new_weights.append(w.flatten())
    return new_weights


def dim_list():
    dim_list = []
    for layer in model.layers:
        weights = layer.get_weights()
        # new_weights = [np.zeros(w.shape) for w in weights]
        new_weights = []
        for w in weights:
            # print(w.shape)
            size = 1
            for sz in w.shape:
               size = size * sz
            dim_list.append(size)
    return dim_list


def cost_function(position):
    idx = 0
    for layer in model.layers:
        weights = layer.get_weights()
        # new_weights = [np.zeros(w.shape) for w in weights]
        new_weights = []
        for w in weights:
            tmp_arr = position[idx]
            idx = idx + 1
            tmp_arr = list(np.reshape(np.array(tmp_arr),w.shape))
            new_weights.append(np.array(tmp_arr, dtype='f'))
        layer.set_weights(new_weights)
    y_pred = get_predictions(model, X_train);
    mae = mean_absolute_error(y_pred, y_train)
    return mae


# Update the weights manually
# update_weights(model)
# print(dim_list(model))

# %%
class wolf:
  def __init__(self, dim_list, minx, maxx, seed):
    self.rnd = random.Random(seed)
    self.position = get_weights()
    # self.position = []
    # for x in dim_list:
    #   self.tmp = [0.0 for i in range(x)]
    #   self.position.append(np.array(self.tmp, dtype = 'f'))
    # for i in range(len(self.position)):
    #   self.tmp = self.position[i];
    #   for j in range(len(self.tmp)):
    #     self.tmp[j] = ((maxx - minx) * self.rnd.random() + minx)
    #   self.position[i] = self.tmp
    self.fitness = cost_function(self.position) # curr fitness

# %%
def gwo(max_iter, n, dim_list, minx, maxx):
    rnd = random.Random(0)

    # create n random wolves
    population = [ wolf(dim_list, minx, maxx, i) for i in range(n)]


    # for i in range(n):
    #    print(population[i].fitness)

    Iter = 0

    # On the basis of fitness values of wolves
    # sort the population in asc order
    population = sorted(population, key = lambda temp: temp.fitness)

    # best 3 solutions will be called as
    # alpha, beta and gaama
    alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])


    # main loop of gwo
    while Iter < max_iter + 1:

        # after every 10 iterations
        # print iteration number and best fitness value so far
        # if Iter % 10 == 0 and Iter > 1:
        #     print("Iter = " + str(Iter) + " best fitness = %.3f" % alpha_wolf.fitness)

        # linearly decreased from 2 to 0
        a = 2*(1 - Iter/max_iter)

        # updating each population member with the help of best three members
        for i in range(n):
            A1, A2, A3 = a * (2 * rnd.random() - 1), a * (
              2 * rnd.random() - 1), a * (2 * rnd.random() - 1)
            C1, C2, C3 = 2 * rnd.random(), 2*rnd.random(), 2*rnd.random()

            tmp_position = []

            for j in range(len(population[i].position)):
                # A1, A2, A3 = a * (2 * rnd.random() - 1), a * (
                # 2 * rnd.random() - 1), a * (2 * rnd.random() - 1)
                # C1, C2, C3 = 2 * rnd.random(), 2*rnd.random(), 2*rnd.random()
                X1 = [0.0 for i in range(len(population[i].position[j]))]
                X2 = [0.0 for i in range(len(population[i].position[j]))]
                X3 = [0.0 for i in range(len(population[i].position[j]))]
                Xnew = [0.0 for i in range(len(population[i].position[j]))]
                for k in range(len(population[i].position[j])):
                    X1[k] = alpha_wolf.position[j][k] - A1 * abs(
                      C1 * alpha_wolf.position[j][k] - population[i].position[j][k])
                    X2[k] = beta_wolf.position[j][k] - A2 * abs(
                      C2 *  beta_wolf.position[j][k] - population[i].position[j][k])
                    X3[k] = gamma_wolf.position[j][k] - A3 * abs(
                      C3 * gamma_wolf.position[j][k] - population[i].position[j][k])
                    Xnew[k] += (X1[k] + X2[k] + X3[k])

                for k in range(len(population[i].position[j])):
                    Xnew[k] /= 3.0

                tmp_position.append(np.array(Xnew, dtype = 'f'))

            #fitness calculation of new solution
            fnew = cost_function(tmp_position)

            # greedy selection
            if fnew < population[i].fitness:
                population[i].position = tmp_position
                population[i].fitness = fnew


        # On the basis of fitness values of wolves
        # sort the population in asc order
        population = sorted(population, key = lambda temp: temp.fitness)

        # for i in range(len(population)):
        #     print(population[i].fitness)

        # best 3 solutions will be called as
        # alpha, beta and gaama
        alpha_wolf, beta_wolf, gamma_wolf = copy.copy(population[: 3])

        print('Top three fitness values of Iteration -', Iter)
        print(alpha_wolf.fitness)
        print(beta_wolf.fitness)
        print(gamma_wolf.fitness)

        Iter+= 1
    # end-while

    # # returning the best solution
    return alpha_wolf.position

# %%
dim = dim_list()
# -0.8, 1.2
position = gwo(100, 10, dim, -1, 2)
# # position = gwo(20, 20, dim, -1, 1)
# position = gwo(50, 10, dim, -0.8, 1.2)
update_weights(position)
# Out:
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 4ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 0
# 0.006031608402232635
# 0.006031608402232635
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 1
# 0.006031608402232635
# 0.006031608402232635
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 2
# 0.006031608402232635
# 0.006031608402232635
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 3
# 0.006031608402232635
# 0.006031608402232635
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 4
# 0.006030334168478791
# 0.006031608402232635
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 5
# 0.006030334168478791
# 0.006031608402232635
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 6
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 7
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 8
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 9
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 10
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 11
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 12
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 13
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 14
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 15
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 16
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 17
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 18
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 19
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 20
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 21
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 22
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 23
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 24
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 25
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 26
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 27
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 28
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 29
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 30
# 0.006026694932247408
# 0.006030334168478791
# 0.006031608402232635
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 31
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 32
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 33
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 34
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 35
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 36
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 37
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 38
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 39
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 40
# 0.006025277857357621
# 0.006026694932247408
# 0.006030334168478791
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 41
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 42
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 43
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 44
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 45
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 46
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 47
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 48
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 49
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 50
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 51
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 52
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 53
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 54
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 55
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 56
# 0.006025277857357621
# 0.006026694932247408
# 0.0060300765074255205
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 57
# 0.006025277857357621
# 0.006026694932247408
# 0.006029779416297426
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 58
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 59
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 60
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 61
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 62
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 63
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 64
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 65
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 66
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 67
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 68
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 69
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 70
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 71
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 72
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 73
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# ...
# Top three fitness values of Iteration - 75
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 76
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 77
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 78
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 79
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 80
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 81
# 0.0060252328714069615
# 0.006025277857357621
# 0.006027399277088795
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 82
# 0.0060252328714069615
# 0.006025277857357621
# 0.006026045374519354
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 83
# 0.0060252328714069615
# 0.006025277857357621
# 0.006026045374519354
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 84
# 0.0060252328714069615
# 0.006025277857357621
# 0.006026045374519354
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 85
# 0.0060252328714069615
# 0.006025277857357621
# 0.006026045374519354
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 86
# 0.0060251487177198
# 0.0060252328714069615
# 0.006025277857357621
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 87
# 0.0060251487177198
# 0.0060252328714069615
# 0.006025277857357621
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 88
# 0.0060251487177198
# 0.0060252328714069615
# 0.006025277857357621
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 89
# 0.0060251487177198
# 0.0060252328714069615
# 0.006025277857357621
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 90
# 0.0060251487177198
# 0.0060252328714069615
# 0.006025277857357621
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 91
# 0.0060251487177198
# 0.0060252328714069615
# 0.006025277857357621
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 92
# 0.0060251487177198
# 0.0060252328714069615
# 0.006025277857357621
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 93
# 0.0060251487177198
# 0.0060252328714069615
# 0.006025277857357621
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 94
# 0.0060251487177198
# 0.006025171059827602
# 0.0060252328714069615
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 95
# 0.0060251487177198
# 0.006025171059827602
# 0.006025206546050535
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 96
# 0.0060251487177198
# 0.006025171059827602
# 0.006025206546050535
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 97
# 0.0060251487177198
# 0.006025171059827602
# 0.006025206546050535
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# Top three fitness values of Iteration - 98
# 0.0060251487177198
# 0.006025152174909194
# 0.006025206546050535
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 99
# 0.0060251487177198
# 0.006025152174909194
# 0.006025193317044249
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 3ms/step
# 63/63 [==============================] - 0s 2ms/step
# Top three fitness values of Iteration - 100
# 0.0060251487177198
# 0.006025150774677072
# 0.006025150774677072

# %%
test_predictions = get_predictions(model, X_test)
train_predictions = get_predictions(model, X_train)
plot_predictions(y_test, test_predictions, 'performance on test data')
plot_predictions(y_train, train_predictions, 'performance on train data')
# Out:
# 16/16 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step

# %%
GWO_MSE = mean_squared_error(y_test, test_predictions)
GWO_MAE = mean_absolute_error(y_test, test_predictions)
GWO_RMSE = math.sqrt(GWO_MSE)
GWO_SMAPE = smape(y_test, test_predictions)
GWO_MSE_T = mean_squared_error(y_train, train_predictions)
GWO_MAE_T = mean_absolute_error(y_train, train_predictions)
GWO_RMSE_T = math.sqrt(GWO_MSE)
GWO_SMAPE_T = smape(y_train, train_predictions)
print('Training MAE - ', GWO_MAE)
print('Testing MAE - ', GWO_MAE_T)
# Out:
# Training MAE -  0.03656388309557757
# Testing MAE -  0.0060251487177198

# %%
# X = ['MSE','MAE','RMSE']
# LSTM = [LSTM_MSE,LSTM_MAE,LSTM_RMSE, LSTM_SMAPE]
# GWO = [GWO_MSE,GWO_MAE,GWO_RMSE, GWO_SMAPE]

# X_axis = np.arange(len(X))

# plt.bar(X_axis - 0.2, LSTM, 0.4, label = 'LSTM')
# plt.bar(X_axis + 0.2, GWO, 0.4, label = 'GWO-LSTM')

# plt.xticks(X_axis, X)
# plt.xlabel("Metrics")
# plt.ylabel("Values")
# plt.title("Comparison of Difference Metrics")
# plt.legend()
# plt.show()

from prettytable import PrettyTable
myTable = PrettyTable(["Model", "MSE", "MAE", "RMSE", "SMAPE"])

# Add rows
myTable.add_row(["Bi-GRU", LSTM_MSE, LSTM_MAE, LSTM_RMSE, LSTM_SMAPE])
myTable.add_row(["Bi-GRU-GWO", GWO_MSE,GWO_MAE,GWO_RMSE, GWO_SMAPE])

print('****************************Testing Performance Comparison*********************************')

print(myTable)
# Out:
# ****************************Testing Performance Comparison*********************************
# +------------+-----------------------+----------------------+---------------------+--------------------+
# |   Model    |          MSE          |         MAE          |         RMSE        |       SMAPE        |
# +------------+-----------------------+----------------------+---------------------+--------------------+
# |   Bi-GRU   | 0.0021824484362623743 | 0.036550757619156826 | 0.04671668263332034 | 11.750549168321918 |
# | Bi-GRU-GWO | 0.0021819872766706203 | 0.03656388309557757  | 0.04671174666687834 | 11.75533359781828  |
# +------------+-----------------------+----------------------+---------------------+--------------------+

# %%
myTable = PrettyTable(["Model", "MSE", "MAE", "RMSE", "SMAPE"])

# Add rows
myTable.add_row(["Bi-GRU", LSTM_MSE_T, LSTM_MAE_T, LSTM_RMSE_T, LSTM_SMAPE_T])
myTable.add_row(["Bi-GRU-GWO", GWO_MSE_T,GWO_MAE_T,GWO_RMSE_T, GWO_SMAPE_T])

print('****************************Training Performance Comparison*********************************')

print(myTable)
# Out:
# ****************************Training Performance Comparison*********************************
# +---------+------------------------+----------------------+---------------------+-------------------+
# |  Model  |          MSE           |         MAE          |         RMSE        |       SMAPE       |
# +---------+------------------------+----------------------+---------------------+-------------------+
# |   GRU   | 0.00012375595165644963 | 0.006031608402232635 | 0.04671668263332034 | 4.083874979180912 |
# | GRU-GWO | 0.0001235258809957281  |  0.0060251487177198  | 0.04671174666687834 | 4.088125353372498 |
# +---------+------------------------+----------------------+---------------------+-------------------+
